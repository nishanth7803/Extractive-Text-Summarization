# %%
# Installing and importing required libraries
# !pip install spacy
# Out:
# Requirement already satisfied: spacy in c:\users\nisha\.conda\envs\tensorflow_keras\lib\site-packages (3.3.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\nisha\.conda\envs\tensorflow_keras\lib\site-packages (from spacy) (2.0.7)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\users\nisha\.conda\envs\tensorflow_keras\lib\site-packages (from spacy) (0.9.1)
# Requirement already satisfied: thinc<8.1.0,>=8.0.14 in c:\users\nisha\.conda\envs\tensorflow_keras\lib\site-packages (from spacy) (8.0.15)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\nisha\.conda\envs\tensorflow_keras\lib\site-packages (from spacy) (1.0.7)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\nisha\.conda\envs\tensorflow_keras\lib\site-packages (from spacy) (0.6.1)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\nisha\.conda\envs\tensorflow_keras\lib\site-packages (from spacy) (1.22.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in c:\users\nisha\.conda\envs\tensorflow_keras\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: jinja2 in c:\users\nisha\.conda\envs\tensorflow_keras\lib\site-packages (from spacy) (3.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\nisha\.conda\envs\tensorflow_keras\lib\site-packages (from spacy) (2.28.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\nisha\.conda\envs\tensorflow_keras\lib\site-packages (from spacy) (4.64.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\nisha\.conda\envs\tensorflow_keras\lib\site-packages (from spacy) (21.3)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\nisha\.conda\envs\tensorflow_keras\lib\site-packages (from spacy) (0.4.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\nisha\.conda\envs\tensorflow_keras\lib\site-packages (from spacy) (2.4.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\nisha\.conda\envs\tensorflow_keras\lib\site-packages (from spacy) (1.8.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\nisha\.conda\envs\tensorflow_keras\lib\site-packages (from spacy) (2.0.6)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\nisha\.conda\envs\tensorflow_keras\lib\site-packages (from spacy) (0.7.7)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\nisha\.conda\envs\tensorflow_keras\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: setuptools in c:\users\nisha\.conda\envs\tensorflow_keras\lib\site-packages (from spacy) (61.2.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\nisha\.conda\envs\tensorflow_keras\lib\site-packages (from spacy) (3.0.6)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\nisha\.conda\envs\tensorflow_keras\lib\site-packages (from spacy) (1.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\nisha\.conda\envs\tensorflow_keras\lib\site-packages (from packaging>=20.0->spacy) (3.0.4)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\nisha\.conda\envs\tensorflow_keras\lib\site-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\nisha\.conda\envs\tensorflow_keras\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy) (4.1.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\nisha\.conda\envs\tensorflow_keras\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nisha\.conda\envs\tensorflow_keras\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nisha\.conda\envs\tensorflow_keras\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\nisha\.conda\envs\tensorflow_keras\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.11)
# Requirement already satisfied: colorama in c:\users\nisha\.conda\envs\tensorflow_keras\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\nisha\.conda\envs\tensorflow_keras\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\nisha\.conda\envs\tensorflow_keras\lib\site-packages (from jinja2->spacy) (2.1.1)
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation
from heapq import nlargest

# %%
# This is the data I'm using in this task
Text_Data = """Netflix and Animal Logic are excited to announce today that Netflix plans to acquire the Australian animation studio.* This acquisition will support Netflix’s ambitious animated film slate, building on films like Academy Award-nominated Over the Moon, Academy Award-nominated Klaus and the recently released The Sea Beast.Animal Logic has been producing award-winning design, visual effects and animation for over 30 years. Headquartered in Sydney, Animal Logic set up a second studio in Vancouver, Canada in 2015 and has worked on Hollywood blockbusters including Happy Feet, Legend of the Guardians: The Owls of Ga’Hoole, The LEGO Movies and Peter Rabbit 1 & 2, alongside a catalogue of amazing visual effects work including The Matrix, Moulin Rouge!, 300, and The Great Gatsby.The announcement builds on an already strong partnership between the two companies, with a full slate of films across Animal Logic's Sydney and Vancouver studios including  The Magician’s Elephant, directed by Wendy Rogers, and the recently announced The Shrinking of the Treehorns, directed by Ron Howard, for Netflix.“Netflix has been investing in animation over the past few years and this furthers our commitment to building a world-class animation studio,” said Amy Reinhard, Netflix Vice President of Studio Operations. “Animal Logic is a leading animation studio with innovative technology that will strengthen our existing business and increase our long-term capacity in the animation space, so that we can better entertain our members around the world.”Working with Animal Logic will accelerate the buildout of Netflix’s end-to-end animation production capabilities. The Animal Logic and Netflix Animation teams together will create a global creative production team and an animation studio that will produce some of Netflix’s largest animated film titles. Netflix will continue to work with many other studios around the world for animated series and film needs. Led by CEO and co-founder Zareh Nalbandian, the Animal Logic teams and leadership will remain operating under the Animal Logic brand and will fulfil production of existing and ongoing commitments and continue to collaborate and work with longstanding studio partners. "After 30 years of producing great work with great people, this is the perfect next chapter for Animal Logic," said Nalbandian. "Our values and aspirations could not be more aligned with Netflix, in working with diverse content makers, producing innovative and engaging stories for audiences around the world. Our collective experience and talent will open new doors for all our teams and will empower a new level of creativity in animation."“The strength of our partnership across a number of projects is testament to our shared creative vision," said Animal Logic’s COO Sharon Taylor. "Solidifying our future together felt like a mutually beneficial, natural progression and I am so excited to continue to build on our success together."Animal Logic Entertainment, the producers behind Legend of the Guardians: The Owls of Ga’hoole, Peter Rabbit 1 & 2 and The Shrinking of the Treehorns, will remain independent and continue to collaborate with iconic filmmakers and major studio partners to develop and produce elevated family entertainment with universal appeal. Netflix’s fast-growing original slate of animated features and shorts includes Academy Award-nominated Robin, Robin,Academy Award-nominated Klaus,Kris Pearn’s The Willoughbys,Academy Award-nominated Over the Moon, Back to the Outback directed by Clare Knight and Harry Cripps, Apollo 10 ½: A Space Age Childhood from Richard Linklater, and the recently released The Sea Beast; as well as upcoming releases including Henry Selick’s Wendell & Wild, Nora Twomey’s My Father’s Dragon, Guillermo del Toro’s Pinocchio, Wendy Rogers’ The Magician’s Elephant, and an Aardman sequel to Chicken Run.  Recent animated film acquisitions by Netflix include the Academy Award-nominated The Mitchells vs. The Machines, Vivo!, Spongebob: Sponge on the Run (ex North America), and Wish Dragon. """

# %%
# Having a look ate the stop words which spacy has to offer us
stop_words = list(STOP_WORDS)
stop_words
# Out:
# ['off',
#  'whenever',
#  'from',
#  'twelve',
#  'this',
#  'its',
#  'another',
#  'third',
#  '‘d',
#  'herself',
#  'due',
#  '‘s',
#  'anywhere',
#  'now',
#  'would',
#  'an',
#  'whither',
#  'full',
#  'will',
#  'wherever',
#  'herein',
#  'thereupon',
#  'whereas',
#  'please',
#  'mostly',
#  'each',
#  'nevertheless',
#  'about',
#  'latterly',
#  'doing',
#  'various',
#  'my',
#  'while',
#  'nowhere',
#  '‘m',
#  'behind',
#  'before',
#  'get',
#  'bottom',
#  'nobody',
#  'some',
#  'further',
#  'therefore',
#  'on',
#  'without',
#  'ca',
#  'same',
#  'a',
#  'perhaps',
#  'be',
#  'whatever',
#  'could',
#  'since',
#  'elsewhere',
#  '‘ll',
#  'do',
#  'down',
#  'several',
#  '’m',
#  'yourself',
#  'any',
#  'together',
#  'them',
#  'fifty',
#  'anyone',
#  'or',
#  'alone',
#  'whence',
#  'noone',
#  'quite',
#  'been',
#  'put',
#  'whether',
#  'last',
#  'so',
#  'least',
#  "'s",
#  'next',
#  'make',
#  '’ve',
#  'although',
#  'thru',
#  'beside',
#  'made',
#  'is',
#  'where',
#  'beforehand',
#  'amongst',
#  'over',
#  'me',
#  'himself',
#  'between',
#  'someone',
#  'toward',
#  'hereafter',
#  'many',
#  'ever',
#  'something',
#  'through',
#  'did',
#  'indeed',
#  'during',
#  'myself',
#  'ten',
#  'until',
#  'few',
#  'four',
#  'your',
#  'than',
#  'their',
#  'thence',
#  'up',
#  'hence',
#  'what',
#  'except',
#  'everything',
#  'none',
#  'always',
#  'rather',
#  'whereupon',
#  'after',
#  'forty',
#  'show',
#  'yours',
#  'really',
#  'how',
#  "n't",
#  '’re',
#  'it',
#  'seem',
#  'via',
#  'using',
#  'because',
#  'thus',
#  'say',
#  'already',
#  'was',
#  'whereby',
#  'beyond',
#  'that',
#  'then',
#  'nor',
#  'yourselves',
#  'part',
#  'see',
#  'first',
#  'along',
#  'eight',
#  '’s',
#  'other',
#  'name',
#  'anything',
#  'even',
#  'her',
#  'our',
#  'more',
#  'i',
#  'take',
#  'are',
#  'am',
#  'five',
#  'neither',
#  'if',
#  'below',
#  'hers',
#  'should',
#  'still',
#  'namely',
#  'six',
#  'less',
#  'there',
#  'around',
#  'meanwhile',
#  'fifteen',
#  'above',
#  'enough',
#  'cannot',
#  'across',
#  'once',
#  'top',
#  'whole',
#  'sometime',
#  'whom',
#  'upon',
#  'become',
#  'for',
#  'wherein',
#  'three',
#  'again',
#  'thereby',
#  'they',
#  'ours',
#  'yet',
#  'eleven',
#  'might',
#  '‘ve',
#  'nothing',
#  'go',
#  'within',
#  'we',
#  'everyone',
#  'besides',
#  'throughout',
#  'otherwise',
#  'which',
#  "'ll",
#  'side',
#  'just',
#  'per',
#  'used',
#  'moreover',
#  'those',
#  'move',
#  'against',
#  'thereafter',
#  'hereupon',
#  'the',
#  'under',
#  'as',
#  '’d',
#  'of',
#  'however',
#  'but',
#  'n’t',
#  'keep',
#  'latter',
#  'into',
#  'you',
#  'themselves',
#  'somewhere',
#  'no',
#  'much',
#  'front',
#  'and',
#  'may',
#  'seeming',
#  'else',
#  'must',
#  'nine',
#  'every',
#  'sixty',
#  'only',
#  'hereby',
#  'afterwards',
#  'give',
#  'here',
#  'well',
#  'everywhere',
#  'can',
#  're',
#  'n‘t',
#  'with',
#  'though',
#  'she',
#  'by',
#  'also',
#  'former',
#  '’ll',
#  "'ve",
#  'seemed',
#  'sometimes',
#  'his',
#  'onto',
#  'done',
#  'became',
#  'all',
#  'almost',
#  'empty',
#  'formerly',
#  'ourselves',
#  'who',
#  'own',
#  'such',
#  'back',
#  'serious',
#  'anyway',
#  'does',
#  'others',
#  'unless',
#  'being',
#  'mine',
#  'both',
#  'whose',
#  'becoming',
#  '‘re',
#  'two',
#  'hundred',
#  'seems',
#  'twenty',
#  "'re",
#  'have',
#  'either',
#  'to',
#  'never',
#  'were',
#  'amount',
#  'becomes',
#  'very',
#  'itself',
#  'in',
#  'one',
#  'why',
#  'out',
#  'whoever',
#  'him',
#  'he',
#  "'d",
#  'at',
#  'therein',
#  'somehow',
#  'whereafter',
#  'most',
#  'call',
#  'these',
#  'among',
#  'has',
#  "'m",
#  'not',
#  'too',
#  'when',
#  'anyhow',
#  'towards',
#  'us',
#  'often',
#  'regarding',
#  'had']

# %%
model = spacy.load("en_core_web_sm")
#en_core_web_sm is a small english pipeline trained on written text data

# %%
data = model(Text_Data)

# %%
tokens = []
#iterating through words in data and adding thame to tokens list
for token in data:
    tokens.append(token.text)

# %%
tokens
# Out:
# ['Netflix',
#  'and',
#  'Animal',
#  'Logic',
#  'are',
#  'excited',
#  'to',
#  'announce',
#  'today',
#  'that',
#  'Netflix',
#  'plans',
#  'to',
#  'acquire',
#  'the',
#  'Australian',
#  'animation',
#  'studio',
#  '.',
#  '*',
#  'This',
#  'acquisition',
#  'will',
#  'support',
#  'Netflix',
#  '’s',
#  'ambitious',
#  'animated',
#  'film',
#  'slate',
#  ',',
#  'building',
#  'on',
#  'films',
#  'like',
#  'Academy',
#  'Award',
#  '-',
#  'nominated',
#  'Over',
#  'the',
#  'Moon',
#  ',',
#  'Academy',
#  'Award',
#  '-',
#  'nominated',
#  'Klaus',
#  'and',
#  'the',
#  'recently',
#  'released',
#  'The',
#  'Sea',
#  'Beast',
#  '.',
#  'Animal',
#  'Logic',
#  'has',
#  'been',
#  'producing',
#  'award',
#  '-',
#  'winning',
#  'design',
#  ',',
#  'visual',
#  'effects',
#  'and',
#  'animation',
#  'for',
#  'over',
#  '30',
#  'years',
#  '.',
#  'Headquartered',
#  'in',
#  'Sydney',
#  ',',
#  'Animal',
#  'Logic',
#  'set',
#  'up',
#  'a',
#  'second',
#  'studio',
#  'in',
#  'Vancouver',
#  ',',
#  'Canada',
#  'in',
#  '2015',
#  'and',
#  'has',
#  'worked',
#  'on',
#  'Hollywood',
#  'blockbusters',
#  'including',
#  'Happy',
#  'Feet',
#  ',',
#  'Legend',
#  'of',
#  'the',
#  'Guardians',
#  ':',
#  'The',
#  'Owls',
#  'of',
#  'Ga’Hoole',
#  ',',
#  'The',
#  'LEGO',
#  'Movies',
#  'and',
#  'Peter',
#  'Rabbit',
#  '1',
#  '&',
#  '2',
#  ',',
#  'alongside',
#  'a',
#  'catalogue',
#  'of',
#  'amazing',
#  'visual',
#  'effects',
#  'work',
#  'including',
#  'The',
#  'Matrix',
#  ',',
#  'Moulin',
#  'Rouge',
#  '!',
#  ',',
#  '300',
#  ',',
#  'and',
#  'The',
#  'Great',
#  'Gatsby',
#  '.',
#  'The',
#  'announcement',
#  'builds',
#  'on',
#  'an',
#  'already',
#  'strong',
#  'partnership',
#  'between',
#  'the',
#  'two',
#  'companies',
#  ',',
#  'with',
#  'a',
#  'full',
#  'slate',
#  'of',
#  'films',
#  'across',
#  'Animal',
#  'Logic',
#  "'s",
#  'Sydney',
#  'and',
#  'Vancouver',
#  'studios',
#  'including',
#  ' ',
#  'The',
#  'Magician',
#  '’s',
#  'Elephant',
#  ',',
#  'directed',
#  'by',
#  'Wendy',
#  'Rogers',
#  ',',
#  'and',
#  'the',
#  'recently',
#  'announced',
#  'The',
#  'Shrinking',
#  'of',
#  'the',
#  'Treehorns',
#  ',',
#  'directed',
#  'by',
#  'Ron',
#  'Howard',
#  ',',
#  'for',
#  'Netflix',
#  '.',
#  '“Netflix',
#  'has',
#  'been',
#  'investing',
#  'in',
#  'animation',
#  'over',
#  'the',
#  'past',
#  'few',
#  'years',
#  'and',
#  'this',
#  'furthers',
#  'our',
#  'commitment',
#  'to',
#  'building',
#  'a',
#  'world',
#  '-',
#  'class',
#  'animation',
#  'studio',
#  ',',
#  '”',
#  'said',
#  'Amy',
#  'Reinhard',
#  ',',
#  'Netflix',
#  'Vice',
#  'President',
#  'of',
#  'Studio',
#  'Operations',
#  '.',
#  '“',
#  'Animal',
#  'Logic',
#  'is',
#  'a',
#  'leading',
#  'animation',
#  'studio',
#  'with',
#  'innovative',
#  'technology',
#  'that',
#  'will',
#  'strengthen',
#  'our',
#  'existing',
#  'business',
#  'and',
#  'increase',
#  'our',
#  'long',
#  '-',
#  'term',
#  'capacity',
#  'in',
#  'the',
#  'animation',
#  'space',
#  ',',
#  'so',
#  'that',
#  'we',
#  'can',
#  'better',
#  'entertain',
#  'our',
#  'members',
#  'around',
#  'the',
#  'world',
#  '.',
#  '”Working',
#  'with',
#  'Animal',
#  'Logic',
#  'will',
#  'accelerate',
#  'the',
#  'buildout',
#  'of',
#  'Netflix',
#  '’s',
#  'end',
#  '-',
#  'to',
#  '-',
#  'end',
#  'animation',
#  'production',
#  'capabilities',
#  '.',
#  'The',
#  'Animal',
#  'Logic',
#  'and',
#  'Netflix',
#  'Animation',
#  'teams',
#  'together',
#  'will',
#  'create',
#  'a',
#  'global',
#  'creative',
#  'production',
#  'team',
#  'and',
#  'an',
#  'animation',
#  'studio',
#  'that',
#  'will',
#  'produce',
#  'some',
#  'of',
#  'Netflix',
#  '’s',
#  'largest',
#  'animated',
#  'film',
#  'titles',
#  '.',
#  'Netflix',
#  'will',
#  'continue',
#  'to',
#  'work',
#  'with',
#  'many',
#  'other',
#  'studios',
#  'around',
#  'the',
#  'world',
#  'for',
#  'animated',
#  'series',
#  'and',
#  'film',
#  'needs',
#  '.',
#  'Led',
#  'by',
#  'CEO',
#  'and',
#  'co',
#  '-',
#  'founder',
#  'Zareh',
#  'Nalbandian',
#  ',',
#  'the',
#  'Animal',
#  'Logic',
#  'teams',
#  'and',
#  'leadership',
#  'will',
#  'remain',
#  'operating',
#  'under',
#  'the',
#  'Animal',
#  'Logic',
#  'brand',
#  'and',
#  'will',
#  'fulfil',
#  'production',
#  'of',
#  'existing',
#  'and',
#  'ongoing',
#  'commitments',
#  'and',
#  'continue',
#  'to',
#  'collaborate',
#  'and',
#  'work',
#  'with',
#  'longstanding',
#  'studio',
#  'partners',
#  '.',
#  '"',
#  'After',
#  '30',
#  'years',
#  'of',
#  'producing',
#  'great',
#  'work',
#  'with',
#  'great',
#  'people',
#  ',',
#  'this',
#  'is',
#  'the',
#  'perfect',
#  'next',
#  'chapter',
#  'for',
#  'Animal',
#  'Logic',
#  ',',
#  '"',
#  'said',
#  'Nalbandian',
#  '.',
#  '"',
#  'Our',
#  'values',
#  'and',
#  'aspirations',
#  'could',
#  'not',
#  'be',
#  'more',
#  'aligned',
#  'with',
#  'Netflix',
#  ',',
#  'in',
#  'working',
#  'with',
#  'diverse',
#  'content',
#  'makers',
#  ',',
#  'producing',
#  'innovative',
#  'and',
#  'engaging',
#  'stories',
#  'for',
#  'audiences',
#  'around',
#  'the',
#  'world',
#  '.',
#  'Our',
#  'collective',
#  'experience',
#  'and',
#  'talent',
#  'will',
#  'open',
#  'new',
#  'doors',
#  'for',
#  'all',
#  'our',
#  'teams',
#  'and',
#  'will',
#  'empower',
#  'a',
#  'new',
#  'level',
#  'of',
#  'creativity',
#  'in',
#  'animation',
#  '.',
#  '"“The',
#  'strength',
#  'of',
#  'our',
#  'partnership',
#  'across',
#  'a',
#  'number',
#  'of',
#  'projects',
#  'is',
#  'testament',
#  'to',
#  'our',
#  'shared',
#  'creative',
#  'vision',
#  ',',
#  '"',
#  'said',
#  'Animal',
#  'Logic',
#  '’s',
#  'COO',
#  'Sharon',
#  'Taylor',
#  '.',
#  '"',
#  'Solidifying',
#  'our',
#  'future',
#  'together',
#  'felt',
#  'like',
#  'a',
#  'mutually',
#  'beneficial',
#  ',',
#  'natural',
#  'progression',
#  'and',
#  'I',
#  'am',
#  'so',
#  'excited',
#  'to',
#  'continue',
#  'to',
#  'build',
#  'on',
#  'our',
#  'success',
#  'together',
#  '.',
#  '"Animal',
#  'Logic',
#  'Entertainment',
#  ',',
#  'the',
#  'producers',
#  'behind',
#  'Legend',
#  'of',
#  'the',
#  'Guardians',
#  ':',
#  'The',
#  'Owls',
#  'of',
#  'Ga’hoole',
#  ',',
#  'Peter',
#  'Rabbit',
#  '1',
#  '&',
#  '2',
#  'and',
#  'The',
#  'Shrinking',
#  'of',
#  'the',
#  'Treehorns',
#  ',',
#  'will',
#  'remain',
#  'independent',
#  'and',
#  'continue',
#  'to',
#  'collaborate',
#  'with',
#  'iconic',
#  'filmmakers',
#  'and',
#  'major',
#  'studio',
#  'partners',
#  'to',
#  'develop',
#  'and',
#  'produce',
#  'elevated',
#  'family',
#  'entertainment',
#  'with',
#  'universal',
#  'appeal',
#  '.',
#  'Netflix',
#  '’s',
#  'fast',
#  '-',
#  'growing',
#  'original',
#  'slate',
#  'of',
#  'animated',
#  'features',
#  'and',
#  'shorts',
#  'includes',
#  'Academy',
#  'Award',
#  '-',
#  'nominated',
#  'Robin',
#  ',',
#  'Robin',
#  ',',
#  'Academy',
#  'Award',
#  '-',
#  'nominated',
#  'Klaus',
#  ',',
#  'Kris',
#  'Pearn',
#  '’s',
#  'The',
#  'Willoughbys',
#  ',',
#  'Academy',
#  'Award',
#  '-',
#  'nominated',
#  'Over',
#  'the',
#  'Moon',
#  ',',
#  'Back',
#  'to',
#  'the',
#  'Outback',
#  'directed',
#  'by',
#  'Clare',
#  'Knight',
#  'and',
#  'Harry',
#  'Cripps',
#  ',',
#  'Apollo',
#  '10',
#  '½',
#  ':',
#  'A',
#  'Space',
#  'Age',
#  'Childhood',
#  'from',
#  'Richard',
#  'Linklater',
#  ',',
#  'and',
#  'the',
#  'recently',
#  'released',
#  'The',
#  'Sea',
#  'Beast',
#  ';',
#  'as',
#  'well',
#  'as',
#  'upcoming',
#  'releases',
#  'including',
#  'Henry',
#  'Selick',
#  '’s',
#  'Wendell',
#  '&',
#  'Wild',
#  ',',
#  'Nora',
#  'Twomey',
#  '’s',
#  'My',
#  'Father',
#  '’s',
#  'Dragon',
#  ',',
#  'Guillermo',
#  'del',
#  'Toro',
#  '’s',
#  'Pinocchio',
#  ',',
#  'Wendy',
#  'Rogers',
#  '’',
#  'The',
#  'Magician',
#  '’s',
#  'Elephant',
#  ',',
#  'and',
#  'an',
#  'Aardman',
#  'sequel',
#  'to',
#  'Chicken',
#  'Run',
#  '.',
#  ' ',
#  'Recent',
#  'animated',
#  'film',
#  'acquisitions',
#  'by',
#  'Netflix',
#  'include',
#  'the',
#  'Academy',
#  'Award',
#  '-',
#  'nominated',
#  'The',
#  'Mitchells',
#  'vs.',
#  'The',
#  'Machines',
#  ',',
#  'Vivo',
#  '!',
#  ',',
#  'Spongebob',
#  ':',
#  'Sponge',
#  'on',
#  'the',
#  'Run',
#  '(',
#  'ex',
#  'North',
#  'America',
#  ')',
#  ',',
#  'and',
#  'Wish',
#  'Dragon',
#  '.']

# %%
# Having a look at what punctuation pacakge has to offer us
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
#Since some of the text data also contains line spaces("\n") in it, 
#let us add line space to our punctuation package which helps us in cleaning the data.
punctuation = punctuation + '\n'
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~\n'

# %%
frequency = {}
#iterating through words in our data
for word in data:
    #checking if the word is in stopwords set or not
    if word.text.lower() not in stop_words:
        #checking if the word is in punctuation package or not
        if word.text.lower() not in punctuation:
            if word.text not in frequency.keys():
                #initializing frequency count of the word with 1 if it is not already present in frquency set
                frequency[word.text] = 1
            else:
                #incrementing the frequency by 1 if the word is already present in the frequency set
                frequency[word.text] += 1

# %%
# Now we can see the frequency of the words apart from stop words and punctuations in our data
frequency
# Out:
# {'Netflix': 12,
#  'Animal': 11,
#  'Logic': 12,
#  'excited': 2,
#  'announce': 1,
#  'today': 1,
#  'plans': 1,
#  'acquire': 1,
#  'Australian': 1,
#  'animation': 9,
#  'studio': 7,
#  'acquisition': 1,
#  'support': 1,
#  'ambitious': 1,
#  'animated': 5,
#  'film': 4,
#  'slate': 3,
#  'building': 2,
#  'films': 2,
#  'like': 2,
#  'Academy': 6,
#  'Award': 6,
#  'nominated': 6,
#  'Moon': 2,
#  'Klaus': 2,
#  'recently': 3,
#  'released': 2,
#  'Sea': 2,
#  'Beast': 2,
#  'producing': 3,
#  'award': 1,
#  'winning': 1,
#  'design': 1,
#  'visual': 2,
#  'effects': 2,
#  '30': 2,
#  'years': 3,
#  'Headquartered': 1,
#  'Sydney': 2,
#  'set': 1,
#  'second': 1,
#  'Vancouver': 2,
#  'Canada': 1,
#  '2015': 1,
#  'worked': 1,
#  'Hollywood': 1,
#  'blockbusters': 1,
#  'including': 4,
#  'Happy': 1,
#  'Feet': 1,
#  'Legend': 2,
#  'Guardians': 2,
#  'Owls': 2,
#  'Ga’Hoole': 1,
#  'LEGO': 1,
#  'Movies': 1,
#  'Peter': 2,
#  'Rabbit': 2,
#  '1': 2,
#  '2': 2,
#  'alongside': 1,
#  'catalogue': 1,
#  'amazing': 1,
#  'work': 4,
#  'Matrix': 1,
#  'Moulin': 1,
#  'Rouge': 1,
#  '300': 1,
#  'Great': 1,
#  'Gatsby': 1,
#  'announcement': 1,
#  'builds': 1,
#  'strong': 1,
#  'partnership': 2,
#  'companies': 1,
#  'studios': 2,
#  ' ': 2,
#  'Magician': 2,
#  'Elephant': 2,
#  'directed': 3,
#  'Wendy': 2,
#  'Rogers': 2,
#  'announced': 1,
#  'Shrinking': 2,
#  'Treehorns': 2,
#  'Ron': 1,
#  'Howard': 1,
#  '“Netflix': 1,
#  'investing': 1,
#  'past': 1,
#  'furthers': 1,
#  'commitment': 1,
#  'world': 4,
#  'class': 1,
#  '”': 1,
#  'said': 3,
#  'Amy': 1,
#  'Reinhard': 1,
#  'Vice': 1,
#  'President': 1,
#  'Studio': 1,
#  'Operations': 1,
#  '“': 1,
#  'leading': 1,
#  'innovative': 2,
#  'technology': 1,
#  'strengthen': 1,
#  'existing': 2,
#  'business': 1,
#  'increase': 1,
#  'long': 1,
#  'term': 1,
#  'capacity': 1,
#  'space': 1,
#  'better': 1,
#  'entertain': 1,
#  'members': 1,
#  '”Working': 1,
#  'accelerate': 1,
#  'buildout': 1,
#  'end': 2,
#  'production': 3,
#  'capabilities': 1,
#  'Animation': 1,
#  'teams': 3,
#  'create': 1,
#  'global': 1,
#  'creative': 2,
#  'team': 1,
#  'produce': 2,
#  'largest': 1,
#  'titles': 1,
#  'continue': 4,
#  'series': 1,
#  'needs': 1,
#  'Led': 1,
#  'CEO': 1,
#  'co': 1,
#  'founder': 1,
#  'Zareh': 1,
#  'Nalbandian': 2,
#  'leadership': 1,
#  'remain': 2,
#  'operating': 1,
#  'brand': 1,
#  'fulfil': 1,
#  'ongoing': 1,
#  'commitments': 1,
#  'collaborate': 2,
#  'longstanding': 1,
#  'partners': 2,
#  'great': 2,
#  'people': 1,
#  'perfect': 1,
#  'chapter': 1,
#  'values': 1,
#  'aspirations': 1,
#  'aligned': 1,
#  'working': 1,
#  'diverse': 1,
#  'content': 1,
#  'makers': 1,
#  'engaging': 1,
#  'stories': 1,
#  'audiences': 1,
#  'collective': 1,
#  'experience': 1,
#  'talent': 1,
#  'open': 1,
#  'new': 2,
#  'doors': 1,
#  'empower': 1,
#  'level': 1,
#  'creativity': 1,
#  '"“The': 1,
#  'strength': 1,
#  'number': 1,
#  'projects': 1,
#  'testament': 1,
#  'shared': 1,
#  'vision': 1,
#  'COO': 1,
#  'Sharon': 1,
#  'Taylor': 1,
#  'Solidifying': 1,
#  'future': 1,
#  'felt': 1,
#  'mutually': 1,
#  'beneficial': 1,
#  'natural': 1,
#  'progression': 1,
#  'build': 1,
#  'success': 1,
#  '"Animal': 1,
#  'Entertainment': 1,
#  'producers': 1,
#  'Ga’hoole': 1,
#  'independent': 1,
#  'iconic': 1,
#  'filmmakers': 1,
#  'major': 1,
#  'develop': 1,
#  'elevated': 1,
#  'family': 1,
#  'entertainment': 1,
#  'universal': 1,
#  'appeal': 1,
#  'fast': 1,
#  'growing': 1,
#  'original': 1,
#  'features': 1,
#  'shorts': 1,
#  'includes': 1,
#  'Robin': 2,
#  'Kris': 1,
#  'Pearn': 1,
#  'Willoughbys': 1,
#  'Outback': 1,
#  'Clare': 1,
#  'Knight': 1,
#  'Harry': 1,
#  'Cripps': 1,
#  'Apollo': 1,
#  '10': 1,
#  '½': 1,
#  'Space': 1,
#  'Age': 1,
#  'Childhood': 1,
#  'Richard': 1,
#  'Linklater': 1,
#  'upcoming': 1,
#  'releases': 1,
#  'Henry': 1,
#  'Selick': 1,
#  'Wendell': 1,
#  'Wild': 1,
#  'Nora': 1,
#  'Twomey': 1,
#  'Father': 1,
#  'Dragon': 2,
#  'Guillermo': 1,
#  'del': 1,
#  'Toro': 1,
#  'Pinocchio': 1,
#  '’': 1,
#  'Aardman': 1,
#  'sequel': 1,
#  'Chicken': 1,
#  'Run': 2,
#  'Recent': 1,
#  'acquisitions': 1,
#  'include': 1,
#  'Mitchells': 1,
#  'vs.': 1,
#  'Machines': 1,
#  'Vivo': 1,
#  'Spongebob': 1,
#  'Sponge': 1,
#  'ex': 1,
#  'North': 1,
#  'America': 1,
#  'Wish': 1}

# %%
# Checking out the highest frequency
max_frequency = max(frequency.values())
print(max_frequency)
# Out:
# 12

# %%
#normalizing the frequencies(making all the frequencies fall between 0 and 1)by dividing all the frequencies by higest frequency
for word in frequency.keys():
    frequency[word] = frequency[word]/max_frequency

# %%
frequency
# Out:
# {'Netflix': 1.0,
#  'Animal': 0.9166666666666666,
#  'Logic': 1.0,
#  'excited': 0.16666666666666666,
#  'announce': 0.08333333333333333,
#  'today': 0.08333333333333333,
#  'plans': 0.08333333333333333,
#  'acquire': 0.08333333333333333,
#  'Australian': 0.08333333333333333,
#  'animation': 0.75,
#  'studio': 0.5833333333333334,
#  'acquisition': 0.08333333333333333,
#  'support': 0.08333333333333333,
#  'ambitious': 0.08333333333333333,
#  'animated': 0.4166666666666667,
#  'film': 0.3333333333333333,
#  'slate': 0.25,
#  'building': 0.16666666666666666,
#  'films': 0.16666666666666666,
#  'like': 0.16666666666666666,
#  'Academy': 0.5,
#  'Award': 0.5,
#  'nominated': 0.5,
#  'Moon': 0.16666666666666666,
#  'Klaus': 0.16666666666666666,
#  'recently': 0.25,
#  'released': 0.16666666666666666,
#  'Sea': 0.16666666666666666,
#  'Beast': 0.16666666666666666,
#  'producing': 0.25,
#  'award': 0.08333333333333333,
#  'winning': 0.08333333333333333,
#  'design': 0.08333333333333333,
#  'visual': 0.16666666666666666,
#  'effects': 0.16666666666666666,
#  '30': 0.16666666666666666,
#  'years': 0.25,
#  'Headquartered': 0.08333333333333333,
#  'Sydney': 0.16666666666666666,
#  'set': 0.08333333333333333,
#  'second': 0.08333333333333333,
#  'Vancouver': 0.16666666666666666,
#  'Canada': 0.08333333333333333,
#  '2015': 0.08333333333333333,
#  'worked': 0.08333333333333333,
#  'Hollywood': 0.08333333333333333,
#  'blockbusters': 0.08333333333333333,
#  'including': 0.3333333333333333,
#  'Happy': 0.08333333333333333,
#  'Feet': 0.08333333333333333,
#  'Legend': 0.16666666666666666,
#  'Guardians': 0.16666666666666666,
#  'Owls': 0.16666666666666666,
#  'Ga’Hoole': 0.08333333333333333,
#  'LEGO': 0.08333333333333333,
#  'Movies': 0.08333333333333333,
#  'Peter': 0.16666666666666666,
#  'Rabbit': 0.16666666666666666,
#  '1': 0.16666666666666666,
#  '2': 0.16666666666666666,
#  'alongside': 0.08333333333333333,
#  'catalogue': 0.08333333333333333,
#  'amazing': 0.08333333333333333,
#  'work': 0.3333333333333333,
#  'Matrix': 0.08333333333333333,
#  'Moulin': 0.08333333333333333,
#  'Rouge': 0.08333333333333333,
#  '300': 0.08333333333333333,
#  'Great': 0.08333333333333333,
#  'Gatsby': 0.08333333333333333,
#  'announcement': 0.08333333333333333,
#  'builds': 0.08333333333333333,
#  'strong': 0.08333333333333333,
#  'partnership': 0.16666666666666666,
#  'companies': 0.08333333333333333,
#  'studios': 0.16666666666666666,
#  ' ': 0.16666666666666666,
#  'Magician': 0.16666666666666666,
#  'Elephant': 0.16666666666666666,
#  'directed': 0.25,
#  'Wendy': 0.16666666666666666,
#  'Rogers': 0.16666666666666666,
#  'announced': 0.08333333333333333,
#  'Shrinking': 0.16666666666666666,
#  'Treehorns': 0.16666666666666666,
#  'Ron': 0.08333333333333333,
#  'Howard': 0.08333333333333333,
#  '“Netflix': 0.08333333333333333,
#  'investing': 0.08333333333333333,
#  'past': 0.08333333333333333,
#  'furthers': 0.08333333333333333,
#  'commitment': 0.08333333333333333,
#  'world': 0.3333333333333333,
#  'class': 0.08333333333333333,
#  '”': 0.08333333333333333,
#  'said': 0.25,
#  'Amy': 0.08333333333333333,
#  'Reinhard': 0.08333333333333333,
#  'Vice': 0.08333333333333333,
#  'President': 0.08333333333333333,
#  'Studio': 0.08333333333333333,
#  'Operations': 0.08333333333333333,
#  '“': 0.08333333333333333,
#  'leading': 0.08333333333333333,
#  'innovative': 0.16666666666666666,
#  'technology': 0.08333333333333333,
#  'strengthen': 0.08333333333333333,
#  'existing': 0.16666666666666666,
#  'business': 0.08333333333333333,
#  'increase': 0.08333333333333333,
#  'long': 0.08333333333333333,
#  'term': 0.08333333333333333,
#  'capacity': 0.08333333333333333,
#  'space': 0.08333333333333333,
#  'better': 0.08333333333333333,
#  'entertain': 0.08333333333333333,
#  'members': 0.08333333333333333,
#  '”Working': 0.08333333333333333,
#  'accelerate': 0.08333333333333333,
#  'buildout': 0.08333333333333333,
#  'end': 0.16666666666666666,
#  'production': 0.25,
#  'capabilities': 0.08333333333333333,
#  'Animation': 0.08333333333333333,
#  'teams': 0.25,
#  'create': 0.08333333333333333,
#  'global': 0.08333333333333333,
#  'creative': 0.16666666666666666,
#  'team': 0.08333333333333333,
#  'produce': 0.16666666666666666,
#  'largest': 0.08333333333333333,
#  'titles': 0.08333333333333333,
#  'continue': 0.3333333333333333,
#  'series': 0.08333333333333333,
#  'needs': 0.08333333333333333,
#  'Led': 0.08333333333333333,
#  'CEO': 0.08333333333333333,
#  'co': 0.08333333333333333,
#  'founder': 0.08333333333333333,
#  'Zareh': 0.08333333333333333,
#  'Nalbandian': 0.16666666666666666,
#  'leadership': 0.08333333333333333,
#  'remain': 0.16666666666666666,
#  'operating': 0.08333333333333333,
#  'brand': 0.08333333333333333,
#  'fulfil': 0.08333333333333333,
#  'ongoing': 0.08333333333333333,
#  'commitments': 0.08333333333333333,
#  'collaborate': 0.16666666666666666,
#  'longstanding': 0.08333333333333333,
#  'partners': 0.16666666666666666,
#  'great': 0.16666666666666666,
#  'people': 0.08333333333333333,
#  'perfect': 0.08333333333333333,
#  'chapter': 0.08333333333333333,
#  'values': 0.08333333333333333,
#  'aspirations': 0.08333333333333333,
#  'aligned': 0.08333333333333333,
#  'working': 0.08333333333333333,
#  'diverse': 0.08333333333333333,
#  'content': 0.08333333333333333,
#  'makers': 0.08333333333333333,
#  'engaging': 0.08333333333333333,
#  'stories': 0.08333333333333333,
#  'audiences': 0.08333333333333333,
#  'collective': 0.08333333333333333,
#  'experience': 0.08333333333333333,
#  'talent': 0.08333333333333333,
#  'open': 0.08333333333333333,
#  'new': 0.16666666666666666,
#  'doors': 0.08333333333333333,
#  'empower': 0.08333333333333333,
#  'level': 0.08333333333333333,
#  'creativity': 0.08333333333333333,
#  '"“The': 0.08333333333333333,
#  'strength': 0.08333333333333333,
#  'number': 0.08333333333333333,
#  'projects': 0.08333333333333333,
#  'testament': 0.08333333333333333,
#  'shared': 0.08333333333333333,
#  'vision': 0.08333333333333333,
#  'COO': 0.08333333333333333,
#  'Sharon': 0.08333333333333333,
#  'Taylor': 0.08333333333333333,
#  'Solidifying': 0.08333333333333333,
#  'future': 0.08333333333333333,
#  'felt': 0.08333333333333333,
#  'mutually': 0.08333333333333333,
#  'beneficial': 0.08333333333333333,
#  'natural': 0.08333333333333333,
#  'progression': 0.08333333333333333,
#  'build': 0.08333333333333333,
#  'success': 0.08333333333333333,
#  '"Animal': 0.08333333333333333,
#  'Entertainment': 0.08333333333333333,
#  'producers': 0.08333333333333333,
#  'Ga’hoole': 0.08333333333333333,
#  'independent': 0.08333333333333333,
#  'iconic': 0.08333333333333333,
#  'filmmakers': 0.08333333333333333,
#  'major': 0.08333333333333333,
#  'develop': 0.08333333333333333,
#  'elevated': 0.08333333333333333,
#  'family': 0.08333333333333333,
#  'entertainment': 0.08333333333333333,
#  'universal': 0.08333333333333333,
#  'appeal': 0.08333333333333333,
#  'fast': 0.08333333333333333,
#  'growing': 0.08333333333333333,
#  'original': 0.08333333333333333,
#  'features': 0.08333333333333333,
#  'shorts': 0.08333333333333333,
#  'includes': 0.08333333333333333,
#  'Robin': 0.16666666666666666,
#  'Kris': 0.08333333333333333,
#  'Pearn': 0.08333333333333333,
#  'Willoughbys': 0.08333333333333333,
#  'Outback': 0.08333333333333333,
#  'Clare': 0.08333333333333333,
#  'Knight': 0.08333333333333333,
#  'Harry': 0.08333333333333333,
#  'Cripps': 0.08333333333333333,
#  'Apollo': 0.08333333333333333,
#  '10': 0.08333333333333333,
#  '½': 0.08333333333333333,
#  'Space': 0.08333333333333333,
#  'Age': 0.08333333333333333,
#  'Childhood': 0.08333333333333333,
#  'Richard': 0.08333333333333333,
#  'Linklater': 0.08333333333333333,
#  'upcoming': 0.08333333333333333,
#  'releases': 0.08333333333333333,
#  'Henry': 0.08333333333333333,
#  'Selick': 0.08333333333333333,
#  'Wendell': 0.08333333333333333,
#  'Wild': 0.08333333333333333,
#  'Nora': 0.08333333333333333,
#  'Twomey': 0.08333333333333333,
#  'Father': 0.08333333333333333,
#  'Dragon': 0.16666666666666666,
#  'Guillermo': 0.08333333333333333,
#  'del': 0.08333333333333333,
#  'Toro': 0.08333333333333333,
#  'Pinocchio': 0.08333333333333333,
#  '’': 0.08333333333333333,
#  'Aardman': 0.08333333333333333,
#  'sequel': 0.08333333333333333,
#  'Chicken': 0.08333333333333333,
#  'Run': 0.16666666666666666,
#  'Recent': 0.08333333333333333,
#  'acquisitions': 0.08333333333333333,
#  'include': 0.08333333333333333,
#  'Mitchells': 0.08333333333333333,
#  'vs.': 0.08333333333333333,
#  'Machines': 0.08333333333333333,
#  'Vivo': 0.08333333333333333,
#  'Spongebob': 0.08333333333333333,
#  'Sponge': 0.08333333333333333,
#  'ex': 0.08333333333333333,
#  'North': 0.08333333333333333,
#  'America': 0.08333333333333333,
#  'Wish': 0.08333333333333333}

# %%
sentence_tokens = []
#iterating through sentences in our text data and making a list of them
for sent in data.sents:
    sentence_tokens.append(sent)

# %%
sentence_score = {}
#iterating thorugh tokenized sentences in sentence_tokens list
for sent in sentence_tokens:
    #iterating through words in a sentence
    for word in sent:
        #checking if the word is in frequency list
        if word.text.lower() in frequency.keys():
            if sent not in sentence_score.keys():
                #initializing the sentence score with value equivalent to the frequency of the word
                sentence_score[sent] = frequency[word.text.lower()]
            else:
                #incrementing the sentence score with value equivalent to the frequency of the word
                sentence_score[sent] += frequency[word.text.lower()]

# %%
# Having a look ate the sentence scores
# Sentence score is the sum of frequencies of all the words in that sentence(apart from stop words and punctuations)
sentence_score
# Out:
# {Netflix and Animal Logic are excited to announce today that Netflix plans to acquire the Australian animation studio.: 1.8333333333333335,
#  This acquisition will support Netflix’s ambitious animated film slate, building on films like Academy Award-nominated Over the Moon, Academy Award-nominated Klaus and the recently released The Sea Beast.: 3.3333333333333335,
#  Animal Logic has been producing award-winning design, visual effects and animation for over 30 years.: 2.0,
#  Headquartered in Sydney, Animal Logic set up a second studio in Vancouver, Canada in 2015 and has worked on Hollywood blockbusters including Happy Feet, Legend of the Guardians: The Owls of Ga’Hoole, The LEGO Movies and Peter Rabbit 1 & 2, alongside a catalogue of amazing visual effects work including The Matrix, Moulin Rouge!, 300, and The Great Gatsby.: 3.1666666666666665,
#  The announcement builds on an already strong partnership between the two companies, with a full slate of films across Animal Logic's Sydney and Vancouver studios including  The Magician’s Elephant, directed by Wendy Rogers, and the recently announced The Shrinking of the Treehorns, directed by Ron Howard, for Netflix.: 2.4166666666666665,
#  “Netflix has been investing in animation over the past few years and this furthers our commitment to building a world-class animation studio,” said Amy Reinhard, Netflix Vice President of Studio Operations.: 4.166666666666667,
#  “Animal Logic is a leading animation studio with innovative technology that will strengthen our existing business and increase our long-term capacity in the animation space, so that we can better entertain our members around the world.: 3.833333333333335,
#  ”Working with Animal Logic will accelerate the buildout of Netflix’s end-to-end animation production capabilities.: 1.5833333333333333,
#  The Animal Logic and Netflix Animation teams together will create a global creative production team and an animation studio that will produce some of Netflix’s largest animated film titles.: 4.083333333333333,
#  Netflix will continue to work with many other studios around the world for animated series and film needs.: 2.083333333333333,
#  Led by CEO and co-founder Zareh Nalbandian, the Animal Logic teams and leadership will remain operating under the Animal Logic brand and will fulfil production of existing and ongoing commitments and continue to collaborate and work with longstanding studio partners.: 3.166666666666667,
#  "After 30 years of producing great work with great people, this is the perfect next chapter for Animal Logic," said Nalbandian.: 1.833333333333333,
#  "Our values and aspirations could not be more aligned with Netflix, in working with diverse content makers, producing innovative and engaging stories for audiences around the world.: 1.583333333333333,
#  Our collective experience and talent will open new doors for all our teams and will empower a new level of creativity in animation.: 2.0,
#  "“The strength of our partnership across a number of projects is testament to our shared creative vision," said Animal Logic’s COO Sharon Taylor.: 1.0833333333333333,
#  "Solidifying our future together felt like a mutually beneficial, natural progression and I am so excited to continue to build on our success together.: 1.333333333333333,
#  "Animal Logic Entertainment, the producers behind Legend of the Guardians:: 0.16666666666666666,
#  The Owls of Ga’hoole, Peter Rabbit 1 & 2 and The Shrinking of the Treehorns, will remain independent and continue to collaborate with iconic filmmakers and major studio partners to develop and produce elevated family entertainment with universal appeal.: 2.7500000000000004,
#  Netflix’s fast-growing original slate of animated features and shorts includes Academy Award-nominated Robin, Robin,Academy Award-nominated Klaus,Kris Pearn’s The Willoughbys,Academy Award-nominated Over the Moon, Back to the Outback directed by Clare Knight and Harry Cripps, Apollo 10 ½: A Space Age Childhood from Richard Linklater, and the recently released The Sea Beast; as well as upcoming releases including Henry Selick’s Wendell & Wild, Nora Twomey’s: 4.333333333333333,
#  My Father’s Dragon, Guillermo del Toro’s Pinocchio, Wendy Rogers’ The Magician’s Elephant, and an Aardman sequel to Chicken Run.: 0.25,
#   Recent animated film acquisitions by Netflix include the Academy Award-nominated The Mitchells vs. The Machines, Vivo!, Spongebob: Sponge on the Run (ex North America), and Wish Dragon.: 1.833333333333333}

# %%
sentence_score.values()
# Out:
# dict_values([1.8333333333333335, 3.3333333333333335, 2.0, 3.1666666666666665, 2.4166666666666665, 4.166666666666667, 3.833333333333335, 1.5833333333333333, 4.083333333333333, 2.083333333333333, 3.166666666666667, 1.833333333333333, 1.583333333333333, 2.0, 1.0833333333333333, 1.333333333333333, 0.16666666666666666, 2.7500000000000004, 4.333333333333333, 0.25, 1.833333333333333])

# %%
#assigining the summary length(30% of original text) to a variable named summary_length 
summary_length = int(len(sentence_score)*0.3)
summary_length
# Out:
# 6

# %%
#As our summary_length is 6, the below line of code takes the top 6 sentences from the text 
#with highest sentence scores, and then gives it to us in the form of list elements.
summary = nlargest(summary_length,sentence_score,key=sentence_score.get)

# %%
# Now we need to convert the elements in the list into text form
summary = [word.text for word in summary]
summary
# Out:
# ['Netflix’s fast-growing original slate of animated features and shorts includes Academy Award-nominated Robin, Robin,Academy Award-nominated Klaus,Kris Pearn’s The Willoughbys,Academy Award-nominated Over the Moon, Back to the Outback directed by Clare Knight and Harry Cripps, Apollo 10 ½: A Space Age Childhood from Richard Linklater, and the recently released The Sea Beast; as well as upcoming releases including Henry Selick’s Wendell & Wild, Nora Twomey’s',
#  '“Netflix has been investing in animation over the past few years and this furthers our commitment to building a world-class animation studio,” said Amy Reinhard, Netflix Vice President of Studio Operations.',
#  'The Animal Logic and Netflix Animation teams together will create a global creative production team and an animation studio that will produce some of Netflix’s largest animated film titles.',
#  '“Animal Logic is a leading animation studio with innovative technology that will strengthen our existing business and increase our long-term capacity in the animation space, so that we can better entertain our members around the world.',
#  'This acquisition will support Netflix’s ambitious animated film slate, building on films like Academy Award-nominated Over the Moon, Academy Award-nominated Klaus and the recently released The Sea Beast.',
#  'Led by CEO and co-founder Zareh Nalbandian, the Animal Logic teams and leadership will remain operating under the Animal Logic brand and will fulfil production of existing and ongoing commitments and continue to collaborate and work with longstanding studio partners.']

# %%
summary = ' '.join(summary)
summary
# This gives our final summary
# Out:
# 'Netflix’s fast-growing original slate of animated features and shorts includes Academy Award-nominated Robin, Robin,Academy Award-nominated Klaus,Kris Pearn’s The Willoughbys,Academy Award-nominated Over the Moon, Back to the Outback directed by Clare Knight and Harry Cripps, Apollo 10 ½: A Space Age Childhood from Richard Linklater, and the recently released The Sea Beast; as well as upcoming releases including Henry Selick’s Wendell & Wild, Nora Twomey’s “Netflix has been investing in animation over the past few years and this furthers our commitment to building a world-class animation studio,” said Amy Reinhard, Netflix Vice President of Studio Operations. The Animal Logic and Netflix Animation teams together will create a global creative production team and an animation studio that will produce some of Netflix’s largest animated film titles. “Animal Logic is a leading animation studio with innovative technology that will strengthen our existing business and increase our long-term capacity in the animation space, so that we can better entertain our members around the world. This acquisition will support Netflix’s ambitious animated film slate, building on films like Academy Award-nominated Over the Moon, Academy Award-nominated Klaus and the recently released The Sea Beast. Led by CEO and co-founder Zareh Nalbandian, the Animal Logic teams and leadership will remain operating under the Animal Logic brand and will fulfil production of existing and ongoing commitments and continue to collaborate and work with longstanding studio partners.'

# %% [markdown]
# **Note that this is an extractive text summarization. This means that the summary sentences are directly extracted from our data without any modifications, due to which you may find it a bit lengthy**
